# %%
import pandas as pd

# %%
train = pd.read_csv("/Users/atienojacinta/PYDATA /Pandas/train.csv")

# %%
train.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
train.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
train.nunique()
# Out:
# Row ID           9800
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              49
# Postal Code       626
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
train.groupby('Ship Mode')['Sales'].sum()
# Out:
# Ship Mode
# First Class       3.455723e+05
# Same Day          1.252190e+05
# Second Class      4.499142e+05
# Standard Class    1.340831e+06
# Name: Sales, dtype: float64

# %%
train.groupby('Ship Mode')['Sales'].mean()
# Out:
# Ship Mode
# First Class       230.228020
# Same Day          232.749143
# Second Class      236.547939
# Standard Class    228.849856
# Name: Sales, dtype: float64

# %%
train.groupby('Ship Mode')['Sub-Category'].count()
# Out:
# Ship Mode
# First Class       1501
# Same Day           538
# Second Class      1902
# Standard Class    5859
# Name: Sub-Category, dtype: int64

# %%
train.groupby('Ship Mode').agg({
    'Sales':'sum',
    'Sub-Category':'count',
    'State':'count'
})
# Out:
#                        Sales  Sub-Category  State
# Ship Mode
# First Class     3.455723e+05          1501   1501
# Same Day        1.252190e+05           538    538
# Second Class    4.499142e+05          1902   1902
# Standard Class  1.340831e+06          5859   5859

# %%
train.groupby('Ship Mode').agg({
    'Sales':'sum',
    'Sub-Category':'count',
    'State':'count'
}).reset_index()
# Out:
#         Ship Mode         Sales  Sub-Category  State
# 0     First Class  3.455723e+05          1501   1501
# 1        Same Day  1.252190e+05           538    538
# 2    Second Class  4.499142e+05          1902   1902
# 3  Standard Class  1.340831e+06          5859   5859

# %% [markdown]
# ### Pivot Tables

# %%
pd.pivot_table(data=train,index='Ship Mode',columns='Segment',values='Sales',aggfunc='sum')
# Out:
# Segment            Consumer    Corporate  Home Office
# Ship Mode
# First Class     158104.9470  102580.0539   84887.2564
# Same Day         57452.2730   45121.3230   22645.4430
# Second Class    230125.5356  139045.2908   80743.3530
# Standard Class  702377.7754  401747.4071  236706.1245

# %%
pd.pivot_table(data=train,index='Ship Mode',columns='Segment',values='Sales',aggfunc='count')
# Out:
# Segment         Consumer  Corporate  Home Office
# Ship Mode
# First Class          755        468          278
# Same Day             312        114          112
# Second Class        1003        589          310
# Standard Class      3031       1782         1046

# %%
pd.pivot_table(data=train,index=['Segment','Region'],columns='Ship Mode',values='Sales',aggfunc='count')
# Out:
# Ship Mode            First Class  Same Day  Second Class  Standard Class
# Segment     Region
# Consumer    Central          138        81           213             756
#             East             266        86           290             802
#             South            110        49           175             497
#             West             241        96           325             976
# Corporate   Central          101        13           133             414
#             East             115        45           150             540
#             South             90        15           110             285
#             West             162        41           196             543
# Home Office Central           53        24           101             250
#             East              89        23            81             298
#             South             32        19            40             176
#             West             104        46            88             322

# %%
pd.pivot_table(data=train,index=['Segment','Region'],columns='Ship Mode',values='Sales',aggfunc=['count','sum'])
# Out:
#                           count                                       \
# Ship Mode           First Class Same Day Second Class Standard Class
# Segment     Region
# Consumer    Central         138       81          213            756
#             East            266       86          290            802
#             South           110       49          175            497
#             West            241       96          325            976
# Corporate   Central         101       13          133            414
#             East            115       45          150            540
#             South            90       15          110            285
#             West            162       41          196            543
# Home Office Central          53       24          101            250
#             East             89       23           81            298
#             South            32       19           40            176
# ...

# %% [markdown]
# ### Time Series

# %%
start_date = pd.Timestamp("2025-9-20")

# %%
pd.date_range(start = start_date,periods=5,freq='d')
# Out:
# DatetimeIndex(['2025-09-20', '2025-09-21', '2025-09-22', '2025-09-23',
#                '2025-09-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
train.head(15)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1        2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2        3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3        4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4        5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5        6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 6        7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 7        8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8        9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 9       10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10      11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11      12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12      13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...

# %%
train['Order Date'] = pd.to_datetime(train['Order Date'],format='mixed')

# %%
train['Ship Date'] = pd.to_datetime(train['Ship Date'],format='mixed')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
train.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
import datetime as dt

# %%
train['Order Month'] = train['Order Date'].dt.month

# %%
train.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
train.groupby('Order Month')['Sales'].sum().sort_values(ascending=False)
# Out:
# Order Month
# 11    268768.7885
# 12    246266.5152
# 9     245155.0671
# 3     212256.1344
# 8     207601.7939
# 10    183851.9562
# 5     166000.7467
# 7     159472.5865
# 1     155990.9154
# 4     142984.2481
# 6     142034.7713
# 2     131153.2594
# Name: Sales, dtype: float64

# %%
train['Order Date'].dt.year
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2016
# 4       2016
#         ...
# 9795    2017
# 9796    2016
# 9797    2016
# 9798    2016
# 9799    2016
# Name: Order Date, Length: 9800, dtype: int32

# %%
train['Order Year'] = train['Order Date'].dt.year

# %%
train.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
train.groupby('Order Year')['Sales'].sum().sort_values(ascending=False)
# Out:
# Order Year
# 2018    722052.0192
# 2017    600192.5500
# 2015    479856.2081
# 2016    459436.0054
# Name: Sales, dtype: float64

# %%
train['VAT'] = train['Sales'].apply(lambda x: x * 0.15)

# %%
train.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Resample

# %%
train2 = train.copy()

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   datetime64[ns]
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
train2.set_index('Order Date',inplace=True)

# %%
train2.resample('QE')['Sales'].sum()
# Out:
# Order Date
# 2015-03-31     95444.4300
# 2015-06-30     83411.8406
# 2015-09-30    138500.2233
# 2015-12-31    162499.7142
# 2016-03-31     84565.4160
# 2016-06-30     97334.4352
# 2016-09-30    143003.2370
# 2016-12-31    134532.9172
# 2017-03-31    135945.9150
# 2017-06-30    144628.9808
# 2017-09-30    128221.0637
# 2017-12-31    191396.5905
# 2018-03-31    183444.5482
# 2018-06-30    125644.5095
# 2018-09-30    202504.9235
# 2018-12-31    210458.0380
# Freq: QE-DEC, Name: Sales, dtype: float64

# %%
date['Order Date']
