# %%
import pandas as pd

# %%
titanic = pd.read_csv("/Users/atienojacinta/PYDATA /Pandas/tested.csv")

# %%
titanic.head()

# %% [markdown]
# ### Perform Column Operations

# %%
titanic['Age'].describe()

# %% [markdown]
# Creating new column

# %%
titanic['New Age'] = titanic['Age'] + 10

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  New Age
# 0   330911   7.8292   NaN        Q     44.5
# 1   363272   7.0000   NaN        S     57.0
# 2   240276   9.6875   NaN        Q     72.0
# 3   315154   8.6625   NaN        S     37.0
# 4  3101298  12.2875   NaN        S     32.0

# %% [markdown]
# Using .apply

# %%
def add_age_label(age):

    if age >= 18:
        return "Adult"
    else:
        return "Child"

# %%
add_age_label(16)
# Out:
# 'Child'

# %%
titanic["Age Label"] = titanic['Age'].apply(add_age_label)

# %%
titanic.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'New Age', 'Age Label'],
#       dtype='object')

# %%
titanic[titanic['Age Label'] == "Adult"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 407         1299         0       1
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [markdown]
# Sorting

# %%
titanic.sort_values('Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 236         1128         0       1
# 305         1197         1       1
# 179         1071         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(["Age","New Age"],ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 179         1071         1       1
# 236         1128         0       1
# 305         1197         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Multi Indexing

# %%
d1 = {
    "Date": ['2025-02-02','2025-02-03','2025-02-04','2025-02-05','2025-02-06'],
    "Product": ['DAP','NPK','DAP','NPK','DK-58'],
    "Region": ['Coast','Mt Kenya','Coast','Coast','Mt.Kenya'],
    "Sales": [100,200,400,600,300],
    "Quantity": [2,1,4,7,5]
}

# %%
sales_d1 = pd.DataFrame(d1)

# %% [markdown]
# Convert date column to actual date

# %%
sales_d1['Date'] = pd.to_datetime(sales_d1['Date'])

# %%
sales_d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5 non-null      datetime64[ns]
#  1   Product   5 non-null      object
#  2   Region    5 non-null      object
#  3   Sales     5 non-null      int64
#  4   Quantity  5 non-null      int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 332.0+ bytes

# %%
sales_d1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sales_d1
# Out:
#         Date Product    Region  Sales  Quantity
# 0 2025-02-02     DAP     Coast    100         2
# 1 2025-02-03     NPK  Mt Kenya    200         1
# 2 2025-02-04     DAP     Coast    400         4
# 3 2025-02-05     NPK     Coast    600         7
# 4 2025-02-06   DK-58  Mt.Kenya    300         5

# %%
multi_index_d1 = sales_d1.set_index(['Date','Region'])

# %%
multi_index_d1
# Out:
#                     Product  Sales  Quantity
# Date       Region
# 2025-02-02 Coast        DAP    100         2
# 2025-02-03 Mt Kenya     NPK    200         1
# 2025-02-04 Coast        DAP    400         4
# 2025-02-05 Coast        NPK    600         7
# 2025-02-06 Mt.Kenya   DK-58    300         5

# %%
multi_index_d1.index
# Out:
# MultiIndex([('2025-02-02',    'Coast'),
#             ('2025-02-03', 'Mt Kenya'),
#             ('2025-02-04',    'Coast'),
#             ('2025-02-05',    'Coast'),
#             ('2025-02-06', 'Mt.Kenya')],
#            names=['Date', 'Region'])

# %%
multi_index_d1.iloc[2,0:2]
# Out:
# Product    DAP
# Sales      400
# Name: (2025-02-04 00:00:00, Coast), dtype: object

# %%
multi_index_d1
# Out:
#                     Product  Sales  Quantity
# Date       Region
# 2025-02-02 Coast        DAP    100         2
# 2025-02-03 Mt Kenya     NPK    200         1
# 2025-02-04 Coast        DAP    400         4
# 2025-02-05 Coast        NPK    600         7
# 2025-02-06 Mt.Kenya   DK-58    300         5

# %%
multi_index_d1.loc['2025-02-05','Sales':'Quantity']
# Out:
#         Sales  Quantity
# Region
# Coast     600         7

# %%
multi_index_d1.loc[(slice(None),'Coast'),]
# Out:
#                   Product  Sales  Quantity
# Date       Region
# 2025-02-02 Coast      DAP    100         2
# 2025-02-04 Coast      DAP    400         4
# 2025-02-05 Coast      NPK    600         7

# %% [markdown]
# Joining DataFrames
# - pd.merge
# - pd.join
# - pd.concat

# %%
df1 = pd.DataFrame({
    "ID" : [1,2,3,4],
    "Name" : ["Alice","Bob","Charlie","David"],
    "Subject" : ["Math","English","Science",'Arts']
})

df2 = pd.DataFrame({
    "ID" : [3,4,5,6],
    "Score" : [90,85,80,95],
    "Grade" : ["A","B","C","A"]
})

# %%
df1
# Out:
#    ID     Name  Subject
# 0   1    Alice     Math
# 1   2      Bob  English
# 2   3  Charlie  Science
# 3   4    David     Arts

# %%
df2
# Out:
#    ID  Score Grade
# 0   3     90     A
# 1   4     85     B
# 2   5     80     C
# 3   6     95     A

# %%
pd.merge(df1,df2,on='ID',how='inner')
# Out:
#    ID     Name  Subject  Score Grade
# 0   3  Charlie  Science     90     A
# 1   4    David     Arts     85     B

# %%
pd.merge(df1,df2,on='ID',how='outer')
# Out:
#    ID     Name  Subject  Score Grade
# 0   1    Alice     Math    NaN   NaN
# 1   2      Bob  English    NaN   NaN
# 2   3  Charlie  Science   90.0     A
# 3   4    David     Arts   85.0     B
# 4   5      NaN      NaN   80.0     C
# 5   6      NaN      NaN   95.0     A

# %%
pd.merge(df1,df2,on='ID',how='left')
# Out:
#    ID     Name  Subject  Score Grade
# 0   1    Alice     Math    NaN   NaN
# 1   2      Bob  English    NaN   NaN
# 2   3  Charlie  Science   90.0     A
# 3   4    David     Arts   85.0     B

# %%
pd.merge(df1,df2,on='ID',how='right')
# Out:
#    ID     Name  Subject  Score Grade
# 0   3  Charlie  Science     90     A
# 1   4    David     Arts     85     B
# 2   5      NaN      NaN     80     C
# 3   6      NaN      NaN     95     A

# %%
pd.merge(df2,df1,on='ID',how='left')
# Out:
#    ID  Score Grade     Name  Subject
# 0   3     90     A  Charlie  Science
# 1   4     85     B    David     Arts
# 2   5     80     C      NaN      NaN
# 3   6     95     A      NaN      NaN

# %%
pd.merge(df2,df1,on='ID',how='right')
# Out:
#    ID  Score Grade     Name  Subject
# 0   1    NaN   NaN    Alice     Math
# 1   2    NaN   NaN      Bob  English
# 2   3   90.0     A  Charlie  Science
# 3   4   85.0     B    David     Arts

# %%
df3 = pd.DataFrame({
    "Student_ID" : [1,2,3,4],
    "Name" : ["Alice","Bob","Charlie","David"],
    "Subject" : ["Math","English","Science",'Arts']
})

df4 = pd.DataFrame({
    "ID" : [3,4,5,6],
    "Score" : [90,85,80,95],
    "Grade" : ["A","B","C","A"]
})

# %%
df3
# Out:
#    Student_ID     Name  Subject
# 0           1    Alice     Math
# 1           2      Bob  English
# 2           3  Charlie  Science
# 3           4    David     Arts

# %%
df4
# Out:
#    ID  Score Grade
# 0   3     90     A
# 1   4     85     B
# 2   5     80     C
# 3   6     95     A

# %%
pd.merge(df3,df4,left_on='Student_ID',right_on='ID',how='inner')
# Out:
#    Student_ID     Name  Subject  ID  Score Grade
# 0           3  Charlie  Science   3     90     A
# 1           4    David     Arts   4     85     B

# %% [markdown]
# ### Joins on Indexes

# %%
df3
# Out:
#    Student_ID     Name  Subject
# 0           1    Alice     Math
# 1           2      Bob  English
# 2           3  Charlie  Science
# 3           4    David     Arts

# %%
df4
# Out:
#    ID  Score Grade
# 0   3     90     A
# 1   4     85     B
# 2   5     80     C
# 3   6     95     A

# %%
df3.join(df4,how='inner')
# Out:
#    Student_ID     Name  Subject  ID  Score Grade
# 0           1    Alice     Math   3     90     A
# 1           2      Bob  English   4     85     B
# 2           3  Charlie  Science   5     80     C
# 3           4    David     Arts   6     95     A
