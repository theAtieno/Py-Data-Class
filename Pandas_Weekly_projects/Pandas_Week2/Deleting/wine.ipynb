# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv(url)

# %%
wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
colms_to_drop = [0,3,6,8,10,12,13]

# %%
wine = wine.drop(wine.columns[colms_to_drop],axis=1)

# %%
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
len(wine.columns)
# Out:
# 7

# %%
wine1 = wine.rename(columns={'14.23':'alcohol','1.71':'malic_acid','15.6':'alcalinity_of_ash',	'127':'magnesium',	'3.06':'flavanoids','2.29':'proanthocyanins','1.04':'hue'})

# %%
wine1
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine1.iloc[0:3,wine1.columns.get_loc('alcohol')] = np.nan

# %%
wine1.columns
# Out:
# Index(['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids',
#        'proanthocyanins', 'hue'],
#       dtype='object')

# %%
wine1.head(7)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
# 5    14.39        1.87               14.6         96        2.52
# 6    14.06        2.15               17.6        121        2.51
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine1.iloc[2:4,wine1.columns.get_loc('magnesium')] = np.nan

# %%
wine1.head(7)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine1.fillna({'alcohol': 10, 'magnesium': 100}, inplace=True)

# %%
wine1.head(7)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   alcohol            177 non-null    float64
#  1   malic_acid         177 non-null    float64
#  2   alcalinity_of_ash  177 non-null    float64
#  3   magnesium          177 non-null    float64
#  4   flavanoids         177 non-null    float64
#  5   proanthocyanins    177 non-null    float64
#  6   hue                177 non-null    float64
# dtypes: float64(7)
# memory usage: 9.8 KB

# %%
wine1.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
a = np.random.randint(0, 10, size=10)

# %%
a
# Out:
# array([6, 7, 1, 6, 8, 5, 0, 6, 2, 4])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine1.loc[a,['alcohol','magnesium']] = np.nan

# %%
wine1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   alcohol            169 non-null    float64
#  1   malic_acid         177 non-null    float64
#  2   alcalinity_of_ash  177 non-null    float64
#  3   magnesium          169 non-null    float64
#  4   flavanoids         177 non-null    float64
#  5   proanthocyanins    177 non-null    float64
#  6   hue                177 non-null    float64
# dtypes: float64(7)
# memory usage: 9.8 KB

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine1.isna().sum().sum()
# Out:
# np.int64(16)

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine2 = wine1.dropna()

# %%
wine2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 3 to 176
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   alcohol            169 non-null    float64
#  1   malic_acid         169 non-null    float64
#  2   alcalinity_of_ash  169 non-null    float64
#  3   magnesium          169 non-null    float64
#  4   flavanoids         169 non-null    float64
#  5   proanthocyanins    169 non-null    float64
#  6   hue                169 non-null    float64
# dtypes: float64(7)
# memory usage: 10.6 KB

# %%
wine2.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine2['alcohol'].notna()
# Out:
# 3      True
# 9      True
# 10     True
# 11     True
# 12     True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: alcohol, Length: 169, dtype: bool

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine2.reset_index(drop=True,inplace=True)

# %%
wine2.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.24        2.59               21.0      100.0        2.69
# 1    14.10        2.16               18.0      105.0        3.32
# 2    14.12        1.48               16.8       95.0        2.43
# 3    13.75        1.73               16.0       89.0        2.76
# 4    14.75        1.73               11.4       91.0        3.69
#
#    proanthocyanins   hue
# 0             1.82  1.04
# 1             2.38  1.25
# 2             1.57  1.17
# 3             1.81  1.15
# 4             2.81  1.25

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# delete only the rows where alcohol is missing, but keep rows where magnesium is NaN

# %%
wine3 = wine1.dropna(subset=['alcohol'])

# %%
wine3.isna().sum().sum()
# Out:
# np.int64(0)

# %%
wine3['magnesium'].isna().sum()
# Out:
# np.int64(0)

# %%
wine1[wine1['magnesium'].isna()]
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        NaN        2.76
# 1      NaN        2.36               18.6        NaN        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 4      NaN        1.76               15.2        NaN        3.39
# 5      NaN        1.87               14.6        NaN        2.52
# 6      NaN        2.15               17.6        NaN        2.51
# 7      NaN        1.64               14.0        NaN        2.98
# 8      NaN        1.35               16.0        NaN        3.15
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# 8             1.85  1.01
